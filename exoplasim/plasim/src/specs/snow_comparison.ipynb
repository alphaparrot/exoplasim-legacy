# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sbdarti = np.concatenate((np.array([.970,.970,.970,.970,.970,.970,.970,.970,.970,.970,.970,
      .971,.972,.973,.974,.975,.975,.975,.975,.976,.977,.978,
      .979,.980,.980,.980,.980,.980,.980,.980,.980,.981,.982,
      .983,.984,.985,.985,.985,.985,.986,.987,.988,.989,.990,
      .990,.990,.990,.990,.990,.990,.990,.990,.990,.990,.990,
      .988,.987,.986,.985,.983,.982,.981,.980,.978,.977,.976,
      .975,.973,.972,.971,.970,.968,.967,.966,.965,.965,.965,
      .965,.965,.963,.962,.961,.960,.953,.952,.951,.950,.950,
      .950,.950,.950,.948,.945,.943,.940,.938,.935,.933,.930,
      .928,.925,.923,.920,.918,.915,.913,.910,.908,.907,.906,
      .905,.903,.902,.901,.900,.898,.895,.893,.890,.885,.880,
      .875,.870,.865,.860,.855,.850,.843,.842,.841,.840,.835,
      .830,.825,.820,.810,.800,.790,.780,.771,.762,.753,.745,
      .739,.733,.727,.720,.718,.715,.713,.710,.715,.720,.725,
      .730,.733,.735,.738,.740,.742,.743,.744,.745,.745,.745,
      .745,.745,.743,.742,.741,.740,.732,.724,.716,.710,.692,
      .674,.656,.640,.630,.620,.610,.600,.584,.568,.552,.535,
      .524,.513,.502,.490,.490,.490,.490,.490,.490,.490,.490,
      .490,.492,.493,.494,.495,.495,.495,.495,.495,.495,.495,
      .495,.495,.493,.492,.491,.490,.488,.485,.483,.480,.470,
      .460,.450,.440,.424,.408,.392,.375,.320,.264,.198,.150,
      .134,.118,.101,.085,.074,.063,.051,.040,.036,.032,.028,
      .025,.025,.025,.025,.025,.028,.030,.033,.035,.039,.043,
      .047,.050,.053,.055,.058,.060,.063,.065,.068,.070,.073,
      .075,.078,.080,.083,.085,.088,.090,.093,.095,.098,.100,
      .104,.108,.112,.115,.119,.123,.126,.130,.135,.140,.145,
      .150,.153,.155,.158,.160,.163,.165,.168,.170,.173,.175,
      .178,.180,.184,.188,.192,.195,.204,.213,.222,.230,.238,
      .246,.254,.260,.254,.248,.242,.235,.206,.177,.148,.120,
      .104,.088,.072,.055,.049,.043,.037,.030,.038,.035,.033,
      .030,.028,.025,.023,.020,.023,.022,.021,.020,.018,.017,
      .016,.015,.013,.012,.011,.010,.010,.010,.010,.010,.010,
      .010,.010,.010,.012,.013,.014,.015,.017,.018,.019,.020,
      .022,.023,.024,.025,.025,.025,.025,.025,.027,.030,.032,
      .035,.040,.045,.050,.055,.059,.063,.067,.070,.074,.078,
      .082,.085,.089,.093,.097,.100,.102,.103,.104,.105,.109,
      .113,.117,.120,.124,.128,.132,.135,.130,.125,.120,.115,
      .108,.100,.092,.085,.081,.077,.073,.070,.068,.065,.063,
      .062,.058,.055,.053,.050,.048,.047,.046,.045,.042,.040,
      .038,.035,.033,.032,.031,.030,.030,.030,.030,.030,.028,
      .027,.026,.025,.025,.025,.025,.025,.025,.025,.025,.025,
      .025,.025,.025,.025,.025,.025,.025,.025,.025,.025,.025,
      .025,.025,.025,.025,.025,.023,.022,.021,.020,.018,.017,
      .016,.015,.013,.012,.011,.010,.008,.007,.006,.005,.003,
      .002,.001,.000]),np.zeros(264)))
wlalb2 = np.zeros(len(sbdarti))
for n in range(0,len(wlalb2)):
    wlalb2[n] = 0.25 + (4.0-0.25)*float(n)/(len(wlalb2)-1)

# %%
plt.plot(wlalb2,sbdarti)
plt.xscale('log')
plt.yscale('log')

# %%
manifest = {}
with open("manifest.txt","r") as mn:
    lines = mn.read().split('\n')
    for l in lines:
        lfile = l.split()
        if len(lfile)>0:
            manifest[lfile[0]] = lfile[1]

# %%
names = sorted(manifest.keys())
ix = 0
for n in names:
    print ix,n
    ix+=1
# Out:
# 0 andesitefine
# 1 andesitesolid
# 2 basaltsolid
# 3 brownsand
# 4 clearice
# 5 coarsesnow
# 6 dunesand
# 7 finesnow
# 8 frost
# 9 mediumsnow
# 10 seafoam
# 11 seawater
# 12 tapwater
# 13 yellowloam
# 14 yellowsand

# %%
ids = [4,5,7,8,9,12]

# %%
for i in ids:
    print names[i]
# Out:
# clearice
# coarsesnow
# finesnow
# frost
# mediumsnow
# tapwater

# %%
weights = np.array([0.1,0.6,0.0,0.1,0.0,0.2])
#weights[0] = 1.75*weights[0]
#weights[-1] = 1.75*weights[-1]
#weights[1:-1] -= (weights[0]+weights[-1])/1.75*0.75/len(weights[1:-1])

# %%
print np.sum(weights),weights
# Out:
# 1.0 [0.1 0.6 0.  0.1 0.  0.2]

# %%
wvref = np.loadtxt("wvref.txt")

# %%
print wvref.shape
# Out:
# (965,)

# %%
specs = np.zeros((len(ids),wvref.shape[0]))

# %%
for idn in range(len(ids)):
    filename = manifest[names[ids[idn]]]
    with open(filename,"r") as fileobj:
        text = fileobj.read().split('\n')
        for k in range(len(text)):
            if text[k].split()[0]=="Additional":
                nhead = k+2
                break
    spec = np.loadtxt(filename,skiprows=nhead,ndmin=2).transpose()
    if spec[0,0] > spec[0,-1]:
        spec = np.flip(spec,axis=1)
    specs[idn,:] = np.interp(wvref,spec[0,:],spec[1,:])

# %%
for idn in range(len(ids)):
    plt.plot(wvref,specs[idn,:],label=names[ids[idn]])
plt.xscale('log')
plt.legend()
plt.yscale('log')
plt.axvline(3.0,linestyle='--',color='k')
plt.axvline(4.0,linestyle='--',color='k')

# %%
for idn in range(len(ids)):
    plt.plot(wvref,specs[idn,:],label=names[ids[idn]])
plt.plot(wlalb2,sbdarti*100,label="SBDART Snow")
plt.xscale('log')
#plt.yscale('log')
plt.legend()

# %%
for idn in range(-3,0):
    plt.plot(wvref,specs[idn,:],label=names[ids[idn]])
plt.xscale('log')
plt.legend()

# %%
wtspec = np.copy(specs)
for n in range(len(ids)):
    wtspec[n,:] *= weights[n]

# %%
netspec = np.sum(wtspec,axis=0)

# %%
plt.plot(wvref,netspec)
plt.xscale('log')

# %%
plt.plot(wvref,netspec)
plt.plot(wlalb2,sbdarti*100)
plt.xscale('log')
plt.yscale('log')

# %%
for n in range(len(ids)):
    plt.plot(wvref,np.sum(wtspec[:n+1,:],axis=0),label=names[ids[n]])
plt.xscale('log')
plt.legend()
plt.xlim(wvref.min(),wvref.max())
# Out:
# (0.34, 14.01)

# %%
import colormatch as cm

# %%
print np.sum(weights)
# Out:
# 1.0

# %%
def bbtemp(teff,wvref):
    sbk = 5.67e-8
    const = 0.0143877735383
    bbf = 1.0/wvref**5 * (1.0/(np.exp(const/(teff*wvref*1e-6))-1))
    return bbf

# %%
rgbs = []
srgbs = []
albs = []
stemps = np.linspace(2800,7900,num=18)
print stemps
bbs = []
for s in range(0,len(stemps)):
    bbf = bbtemp(stemps[s]-650.0,wvref)
    bbs.append(bbtemp(stemps[s]-650.0,wvref))
    refl = netspec*0.01*bbf
    albb = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bbf[:145],x=wvref[:145])
    albs.append(albb)
    #srgbs.append(cm.specs2rgb(wvref*1e3,[bbf,]))
    rgbs.append(cm.spec2rgb(wvref*1e3,refl,normalization=albb))
srgbs = cm.specs2rgb(wvref*1e3,np.array(bbs))
for s in range(len(stemps)):
    print np.array(rgbs[s])/np.amax(rgbs[s])*albs[s],np.sqrt(np.array(rgbs[s])/np.amax(rgbs[s])*albs[s])
# Out:
# [2800. 3100. 3400. 3700. 4000. 4300. 4600. 4900. 5200. 5500. 5800. 6100.
#  6400. 6700. 7000. 7300. 7600. 7900.]
# [0.20857395 0.16542083 0.03547318] [0.45669897 0.4067196  0.18834324]
# [0.25324305 0.21255369 0.06498947] [0.5032326  0.46103546 0.25493031]
# [0.29578739 0.25952389 0.10441319] [0.5438634  0.50943487 0.32313029]
# [0.33517089 0.30450069 0.15239303] [0.57893945 0.55181581 0.39037549]
# [0.37091877 0.346344   0.20699475] [0.60903101 0.58850998 0.45496676]
# [0.4029145  0.38445266 0.26613574] [0.63475547 0.62004247 0.51588346]
# [0.43126327 0.4186148  0.32786932] [0.65670638 0.64700449 0.57259874]
# [0.45620098 0.44888204 0.39053527] [0.67542652 0.66998659 0.62492821]
# [0.47803255 0.47547103 0.45281365] [0.69139898 0.68954407 0.6729143 ]
# [0.48100016 0.48254869 0.4970899 ] [0.69354175 0.69465724 0.70504603]
# [0.46090225 0.46555324 0.51370424] [0.67889782 0.68231462 0.71673164]
# [0.44362274 0.45053465 0.52818892] [0.6660501  0.67121878 0.72676607]
# [0.42861906 0.43716992 0.54083005] [0.65469005 0.66118826 0.73541148]
# [0.41548268 0.42520912 0.5518825 ] [0.64457946 0.65208061 0.74288794]
# [0.40389895 0.41445356 0.56156939] [0.63553045 0.64378067 0.74937934]
# [0.39362074 0.40474184 0.57008372] [0.62739202 0.63619324 0.75503888]
# [0.38445072 0.39594054 0.57759102] [0.6200409  0.62923806 0.75999409]
# [0.37622907 0.38793788 0.58423253] [0.61337515 0.62284659 0.76435105]

# %%
fig,ax=plt.subplots(figsize=(13,4))
for s in range(len(stemps)):
    plt.scatter(stemps[s],1.0,marker='o',color=(np.array(rgbs[s])/np.amax(rgbs[s])*albs[s])**0.1,s=1000)
    plt.scatter(stemps[s],1.25,marker='o',color=np.array(srgbs[s])/np.amax(srgbs[s]),s=1000)
    #plt.annotate("%d K"%stemps[s],(stemps[s]-100,1.35))
    #print stemps[s]
    #plt.axvline(stemps[s])
ax.set_facecolor('0.8')
plt.annotate("Stellar Color",(3000,1.35),color='k',fontsize=18)
plt.annotate("Surface Color",(3000,1.1),color='k',fontsize=18)
plt.ylim(0.9,1.4)
plt.xlim(2500,8200)
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    right=False,         # ticks along the top edge are off
    labelleft=False)
plt.xlabel("Stellar Effective Temperature [K]")
plt.title("Snow/Ice Color")
#plt.savefig("colorgrid_snow.png",bbox_inches='tight')
# Out:
# Text(0.5,1,'Snow/Ice Color')

# %%
alb1 = np.zeros(100)
alb2 = np.zeros(100)
albb = np.zeros(100)
teffs = np.linspace(2700,6000,num=100)

# %%
for n in range(100):
    bbf = bbtemp(teffs[n],wvref)
    refl = netspec*0.01*bbf
    alb1[n] = np.trapz(refl[:42],x=wvref[:42])/np.trapz(bbf[:42],x=wvref[:42])
    alb2[n] = np.trapz(refl[42:145],x=wvref[42:145])/np.trapz(bbf[42:145],x=wvref[42:145])
    albb[n] = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bbf[:145],x=wvref[:145])

# %%
plt.plot(teffs,alb1,label="$\lambda<{0.75}$ $\mu$m")
plt.plot(teffs,alb2,label="$\lambda>{0.75}$ $\mu$m")
plt.plot(teffs,albb,label='Bolometric albedo')
plt.legend(loc='best')
plt.xlabel("Star T$_{eff}$ [K]")
plt.ylabel("Albedo")
plt.title("Snow/Ice albedo with different stars")
#plt.savefig("snow_bolometric.png",bbox_inches='tight')
# Out:
# Text(0.5,1,'Snow/Ice albedo with different stars')

# %%
print teffs[-16],albb[-7]
# Out:
# 5500.0 0.5427760351313607

# %%
specvar = "meltpools"
specinttext = "       real :: %s(%d) = (/"%(specvar,len(wvref))
specinttext += ",".join(["%.4f" % number for number in netspec[0:8]]) + ", &\n"
n=8
while n+8<len(wvref):
    specinttext += "      &          " + ",".join(["%.4f" % number for number in netspec[n:n+8]]) + ", &\n"
    n+=8
specinttext += "      &          " + ",".join(["%.4f" % number for number in netspec[n:]]) + " /)"

# %%
newfilename = "meltpools_interp_f90.txt"
with open(newfilename,"w") as fileobj:
    fileobj.write(specinttext+'\n')

# %%
print specinttext
# Out:
#        real :: meltpools(965) = (/68.3081,68.4223,68.5155,68.5917,68.7017,68.7705,68.8551,68.9984, &
#       &          69.0343,69.1686,69.1950,69.3888,69.4582,69.4716,69.3356,69.3184, &
#       &          69.2730,69.2030,69.1629,69.1112,69.0316,68.9728,68.9263,68.8777, &
#       &          68.7931,68.6912,68.4361,67.9285,68.0270,67.7876,67.5189,67.3312, &
#       &          67.1097,66.7388,66.7346,66.4421,66.0462,65.7570,65.3925,65.2308, &
#       &          64.9095,64.4619,63.9303,63.3456,62.6553,62.2600,61.8786,61.4749, &
#       &          61.4632,59.9939,57.7818,56.5435,55.8810,55.0558,52.9601,50.0947, &
#       &          46.1766,44.0181,43.7329,45.6272,46.9672,47.2586,46.7967,44.9791, &
#       &          42.0827,37.5444,33.7749,28.5297,27.2586,26.4792,26.6290,26.5817, &
#       &          27.0172,27.0183,26.4019,25.4227,23.1424,13.5302,5.7358,4.2125, &
#       &          3.4561,3.0403,3.2141,3.1926,3.7155,4.2059,4.4359,4.4283, &
#       &          5.5256,6.0301,6.8842,7.3507,7.9190,8.1894,8.8801,9.1365, &
#       &          10.2695,10.9054,11.8932,10.5821,6.6335,4.3207,3.0321,2.4405, &
#       &          1.9830,1.8051,1.7249,1.8314,1.9721,2.0771,2.3355,2.7123, &
#       &          3.2536,4.1546,4.7700,5.3450,6.3776,7.0282,7.2043,7.1706, &
#       &          7.0838,6.9045,6.6630,6.4093,6.1665,5.9278,5.7179,5.5525, &
#       &          5.3861,5.2358,5.1291,5.0321,4.9608,4.8815,4.8147,4.7687, &
#       &          4.7061,4.6449,4.5733,4.5171,4.4584,4.3924,4.3419,4.2792, &
#       &          4.1943,4.1395,4.1006,4.0391,3.9769,3.9420,3.8784,3.8194, &
#       &          3.7774,3.6656,3.6223,3.5608,3.4522,3.3393,3.3677,3.1826, &
#       &          2.9561,2.6020,2.4891,2.3047,2.0252,1.7373,1.4457,1.2504, &
#       &          1.0000,0.8691,0.7391,0.6322,0.5692,0.5382,0.4988,0.5032, &
#       &          0.5010,0.5262,0.5566,0.5947,0.6467,0.7050,0.7917,0.9334, &
#       &          1.0790,1.2778,1.4673,1.6887,1.9196,2.1035,2.2697,2.4344, &
#       &          2.5734,2.7593,2.9677,3.2484,3.5683,3.9517,4.3650,4.8431, &
#       &          5.2537,5.6289,5.8428,5.8741,5.7885,5.5722,5.3940,5.2644, &
#       &          5.1877,5.1348,5.0918,5.0406,4.9858,4.8686,4.7504,4.5885, &
#       &          4.4326,4.2722,4.1118,3.9842,3.8628,3.7441,3.6449,3.5516, &
#       &          3.4719,3.4064,3.3296,3.2652,3.2081,3.1603,3.1292,3.0887, &
#       &          3.0223,2.9860,2.9756,2.9644,2.9438,2.9246,2.9013,2.8896, &
#       &          2.8946,2.8943,2.8980,2.9100,2.9271,2.9416,2.9491,2.9929, &
#       &          3.0199,3.0406,3.0653,3.0953,3.1343,3.1616,3.1888,3.2054, &
#       &          3.2296,3.2637,3.2695,3.2846,3.2982,3.2977,3.3031,3.3021, &
#       &          3.2926,3.2684,3.2692,3.2531,3.2151,3.1943,3.1656,3.1327, &
#       &          3.1001,3.0676,3.0317,2.9911,2.9588,2.9308,2.9062,2.8671, &
#       &          2.8186,2.7903,2.7675,2.7284,2.6922,2.6671,2.6459,2.6234, &
#       &          2.6027,2.5769,2.5427,2.5189,2.4981,2.4763,2.4624,2.4406, &
#       &          2.4142,2.3974,2.3736,2.3445,2.3353,2.3347,2.3101,2.2806, &
#       &          2.2698,2.2619,2.2475,2.2384,2.2306,2.2155,2.2059,2.1950, &
#       &          2.1775,2.1710,2.1619,2.1384,2.1195,2.1128,2.1072,2.0947, &
#       &          2.0828,2.0687,2.0553,2.0489,2.0424,2.0248,2.0051,1.9959, &
#       &          1.9958,1.9896,1.9752,1.9632,1.9546,1.9510,1.9506,1.9492, &
#       &          1.9436,1.9294,1.9264,1.9407,1.9510,1.9458,1.9383,1.9411, &
#       &          1.9447,1.9454,1.9493,1.9579,1.9653,1.9708,1.9796,1.9896, &
#       &          1.9970,2.0055,2.0157,2.0309,2.0500,2.0652,2.0744,2.0807, &
#       &          2.0876,2.0978,2.1100,2.1227,2.1388,2.1509,2.1547,2.1619, &
#       &          2.1748,2.1868,2.1970,2.2086,2.2230,2.2375,2.2451,2.2500, &
#       &          2.2579,2.2669,2.2733,2.2833,2.2943,2.3020,2.3078,2.3155, &
#       &          2.3252,2.3327,2.3361,2.3415,2.3507,2.3523,2.3502,2.3509, &
#       &          2.3531,2.3524,2.3531,2.3486,2.3487,2.3536,2.3571,2.3544, &
#       &          2.3527,2.3484,2.3389,2.3300,2.3216,2.3143,2.3131,2.3099, &
#       &          2.2910,2.2738,2.2671,2.2678,2.2606,2.2414,2.2120,2.1944, &
#       &          2.1922,2.1900,2.1850,2.1793,2.1727,2.1557,2.1308,2.1154, &
#       &          2.1110,2.1063,2.0924,2.0742,2.0438,2.0246,2.0250,2.0321, &
#       &          2.0217,2.0027,1.9862,1.9460,1.9168,1.9095,1.9206,1.9021, &
#       &          1.8674,1.8419,1.8414,1.8515,1.8540,1.8428,1.8264,1.8029, &
#       &          1.7748,1.7568,1.7375,1.7146,1.7054,1.7020,1.7010,1.6924, &
#       &          1.6762,1.6422,1.6086,1.5949,1.5978,1.6018,1.5920,1.5778, &
#       &          1.5504,1.5185,1.5060,1.5054,1.5126,1.4838,1.4520,1.4476, &
#       &          1.4637,1.4981,1.5007,1.4621,1.4255,1.4186,1.4358,1.4517, &
#       &          1.4281,1.3846,1.3473,1.3394,1.3644,1.4000,1.3973,1.3788, &
#       &          1.3784,1.3922,1.4181,1.4250,1.4268,1.4467,1.4628,1.4884, &
#       &          1.5112,1.4829,1.4568,1.4324,1.4334,1.4916,1.5594,1.5869, &
#       &          1.5910,1.5899,1.6012,1.6356,1.6597,1.6591,1.6507,1.6410, &
#       &          1.6459,1.6640,1.6802,1.7080,1.7174,1.7134,1.7152,1.7163, &
#       &          1.7182,1.7215,1.7294,1.7363,1.7388,1.7380,1.7137,1.6813, &
#       &          1.6650,1.6514,1.6526,1.6727,1.6800,1.6422,1.5941,1.5478, &
#       &          1.5404,1.5789,1.6496,1.6911,1.6835,1.6389,1.5929,1.5799, &
#       &          1.5900,1.6272,1.6662,1.6780,1.6651,1.6465,1.6245,1.6064, &
#       &          1.6148,1.6392,1.6640,1.6544,1.6215,1.6052,1.6121,1.6363, &
#       &          1.6685,1.6958,1.6981,1.6859,1.6852,1.6952,1.7038,1.7136, &
#       &          1.7335,1.7432,1.7232,1.6867,1.6655,1.6602,1.6635,1.6784, &
#       &          1.7012,1.6985,1.6635,1.6423,1.6426,1.6529,1.6761,1.7084, &
#       &          1.7311,1.7370,1.7407,1.7361,1.7248,1.7126,1.7032,1.7020, &
#       &          1.7105,1.7275,1.7382,1.7334,1.7189,1.7030,1.6942,1.6956, &
#       &          1.7074,1.7246,1.7407,1.7428,1.7354,1.7282,1.7217,1.7152, &
#       &          1.7051,1.7003,1.7004,1.7026,1.7060,1.7108,1.7162,1.7226, &
#       &          1.7234,1.7273,1.7314,1.7271,1.7186,1.7130,1.7118,1.7130, &
#       &          1.7136,1.7103,1.7027,1.6964,1.6940,1.6959,1.7023,1.7107, &
#       &          1.7185,1.7218,1.7269,1.7310,1.7290,1.7208,1.7087,1.6951, &
#       &          1.6834,1.6794,1.6820,1.6916,1.7037,1.7140,1.7185,1.7187, &
#       &          1.7146,1.7076,1.7000,1.6942,1.6919,1.6929,1.6967,1.6990, &
#       &          1.7027,1.7031,1.7014,1.6982,1.6956,1.6946,1.6946,1.6961, &
#       &          1.6979,1.6985,1.6996,1.7001,1.7006,1.7023,1.7036,1.7050, &
#       &          1.7046,1.7017,1.6988,1.6933,1.6917,1.6904,1.6931,1.6967, &
#       &          1.6990,1.7016,1.7019,1.7019,1.7022,1.7027,1.7050,1.7060, &
#       &          1.7058,1.7057,1.7043,1.7038,1.7030,1.7006,1.6999,1.6994, &
#       &          1.6996,1.7014,1.7056,1.7100,1.7109,1.7110,1.7086,1.7045, &
#       &          1.7004,1.6955,1.6894,1.6838,1.6801,1.6774,1.6759,1.6771, &
#       &          1.6795,1.6805,1.6813,1.6791,1.6780,1.6750,1.6742,1.6738, &
#       &          1.6739,1.6709,1.6660,1.6586,1.6478,1.6372,1.6290,1.6247, &
#       &          1.6237,1.6238,1.6271,1.6292,1.6309,1.6291,1.6275,1.6252, &
#       &          1.6203,1.6177,1.6139,1.6110,1.6065,1.6021,1.5990,1.5957, &
#       &          1.5935,1.5938,1.5938,1.5937,1.5896,1.5832,1.5751,1.5676, &
#       &          1.5643,1.5654,1.5688,1.5713,1.5696,1.5632,1.5506,1.5375, &
#       &          1.5277,1.5212,1.5192,1.5195,1.5192,1.5207,1.5182,1.5157, &
#       &          1.5114,1.5077,1.5042,1.5015,1.4990,1.4944,1.4909,1.4886, &
#       &          1.4841,1.4789,1.4737,1.4652,1.4585,1.4520,1.4470,1.4442, &
#       &          1.4428,1.4410,1.4356,1.4300,1.4236,1.4146,1.4051,1.3960, &
#       &          1.3891,1.3852,1.3831,1.3831,1.3829,1.3812,1.3729,1.3603, &
#       &          1.3444,1.3264,1.3098,1.2906,1.2726,1.2558,1.2391,1.2210, &
#       &          1.2058,1.1919,1.1778,1.1623,1.1451,1.1281,1.1095,1.0916, &
#       &          1.0755,1.0602,1.0465,1.0319,1.0214,1.0091,0.9964,0.9829, &
#       &          0.9659,0.9474,0.9218,0.8978,0.8763,0.8590,0.8478,0.8398, &
#       &          0.8352,0.8268,0.8174,0.8052,0.7921,0.7823,0.7777,0.7761, &
#       &          0.7766,0.7797,0.7865,0.7935,0.8042,0.8170,0.8350,0.8563, &
#       &          0.8790,0.9041,0.9337,0.9655,0.9995,1.0313,1.0621,1.0940, &
#       &          1.1305,1.1671,1.2069,1.2486,1.2944,1.3364,1.3794,1.4277, &
#       &          1.4757,1.5239,1.5771,1.6241,1.6678,1.7133,1.7550,1.8020, &
#       &          1.8471,1.8954,1.9408,1.9850,2.0313,2.0723,2.1192,2.1621, &
#       &          2.2085,2.2518,2.3009,2.3443,2.3929,2.4370,2.4741,2.5111, &
#       &          2.5404,2.5725,2.6070,2.6393,2.6772,2.7170,2.7529,2.7927, &
#       &          2.8328,2.8692,2.9105,2.9525,2.9973,3.0382,3.0851,3.1310, &
#       &          3.1747,3.2117,3.2518,3.2900,3.3286,3.3665,3.4043,3.4406, &
#       &          3.4721,3.5047,3.5363,3.5661,3.5918,3.6151,3.6379,3.6616, &
#       &          3.6849,3.7075,3.7328,3.7593,3.7855,3.8136,3.8381,3.8618, &
#       &          3.8814,3.8961,3.9045,3.9103,3.9189,3.9264,3.9364,3.9486, &
#       &          3.9656,3.9749,3.9836,3.9890,3.9940,3.9949,3.9917,3.9903, &
#       &          3.9857,3.9855,3.9920,4.0087,4.0280,4.0490,4.0638,4.0730, &
#       &          4.0740,4.0732,4.0721,4.0706,4.0630,4.0511,4.0354,4.0151, &
#       &          3.9997,3.9920,3.9964,3.9993,3.9978 /)
