# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sbdartw = np.concatenate((np.ones(41)*0.041,
     np.array([.041,.041,.041,.041,.041,.041,.041,.041,.041,.041,.042,
       .043,.044,.044,.046,.047,.049,.050,.052,.054,.055,.056,
      .059,.060,.061,.061,.059,.057,.054,.053,.051,.050,.049,
      .047,.046,.046,.045,.044,.043,.043,.041,.040,.038,.037,
      .037,.036,.033,.032,.031,.029,.027,.024,.023,.021,.018,
      .015,.012,.009,.008,.006,.004,.002,.001,.000,.000,.000]),
      np.zeros(644)))
wlalb = np.zeros(len(sbdartw))
for n in range(0,len(wlalb)):
    wlalb[n] = 0.25 + (4.0-0.25)*float(n)/(len(wlalb)-1)

# %%
plt.plot(wlalb,sbdartw)
plt.xscale('log')

# %%
manifest = {}
with open("manifest.txt","r") as mn:
    lines = mn.read().split('\n')
    for l in lines:
        lfile = l.split()
        if len(lfile)>0:
            manifest[lfile[0]] = lfile[1]

# %%
names = sorted(manifest.keys())
ix = 0
for n in names:
    print ix,n
    ix+=1
# Out:
# 0 andesitefine
# 1 andesitesolid
# 2 basaltsolid
# 3 brownsand
# 4 clearice
# 5 coarsesnow
# 6 dunesand
# 7 finesnow
# 8 frost
# 9 mediumsnow
# 10 seafoam
# 11 seawater
# 12 tapwater
# 13 yellowloam
# 14 yellowsand

# %%
ids = [11,12]

# %%
for i in ids:
    print names[i]
# Out:
# seawater
# tapwater

# %%
weights = np.array([0.0,1.0])

# %%
print np.sum(weights),weights
# Out:
# 1.0 [0. 1.]

# %%
wvref = np.loadtxt("wvref.txt")

# %%
print wvref.shape
# Out:
# (965,)

# %%
specs = np.zeros((len(ids),wvref.shape[0]))

# %%
for idn in range(len(ids)):
    filename = manifest[names[ids[idn]]]
    with open(filename,"r") as fileobj:
        text = fileobj.read().split('\n')
        for k in range(len(text)):
            if text[k].split()[0]=="Additional":
                nhead = k+2
                break
    spec = np.loadtxt(filename,skiprows=nhead,ndmin=2).transpose()
    if spec[0,0] > spec[0,-1]:
        spec = np.flip(spec,axis=1)
    specs[idn,:] = np.interp(wvref,spec[0,:],spec[1,:])

# %%
for idn in range(len(ids)):
    plt.plot(wvref,specs[idn,:],label=names[ids[idn]])
plt.xscale('log')
plt.legend()

# %%
wtspec = np.copy(specs)
for n in range(len(ids)):
    wtspec[n,:] *= weights[n]

# %%
sbdart_winterp = np.interp(wvref,wlalb,sbdartw)*100

# %%
#netspec = np.maximum(np.sum(wtspec,axis=0),sbdart_winterp)*2.1
netspec = np.sum(wtspec,axis=0)*2.71644442896

# %%
plt.plot(wvref,netspec)
plt.xscale('log')

# %%
plt.plot(wvref,np.sum(wtspec,axis=0),label="ECOSTRESS Tapwater")
plt.plot(wlalb,sbdartw*100,label="SBDART Seawater")
plt.plot(wvref,netspec,label="New Spectrum")
plt.xscale('log')
plt.xlabel("Wavelength [$\mu$m]")
plt.ylabel("Reflectance [%]")
plt.legend()
plt.title("Water Reflectance Models")
plt.savefig("ocean_refl_components.pdf",bbox_inches='tight')

# %%
for n in range(len(ids)):
    plt.plot(wvref,np.sum(wtspec[:n+1,:],axis=0)*2,label=names[ids[n]])
plt.xscale('log')
plt.legend()
plt.xlim(wvref.min(),wvref.max())
# Out:
# (0.34, 14.01)

# %%
import colormatch as cm

# %%
print np.sum(weights)
# Out:
# 1.0

# %%
def bbtemp(teff,wvref):
    sbk = 5.67e-8
    const = 0.0143877735383
    bbf = 1.0/wvref**5 * (1.0/(np.exp(const/(teff*wvref*1e-6))-1))
    return bbf

# %%
def readstarspec(filename):
    wv,flux = np.loadtxt(filename,skiprows=1,unpack=True)
    return wv,flux

# %%
rgbs = []
srgbs = []
albs = []
stemps = np.linspace(2800,7900,num=18)
print stemps
bbs = []
for s in range(0,len(stemps)):
    bbf = bbtemp(stemps[s],wvref)
    bbs.append(bbtemp(stemps[s]-650.0,wvref))
    refl = netspec*0.01*bbf
    albb = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bbf[:145],x=wvref[:145])
    albs.append(albb)
    #srgbs.append(cm.specs2rgb(wvref*1e3,[bbf,]))
    rgbs.append(cm.spec2rgb(wvref*1e3,refl,normalization=albb))
srgbs = cm.specs2rgb(wvref*1e3,np.array(bbs))
# Out:
# [2800. 3100. 3400. 3700. 4000. 4300. 4600. 4900. 5200. 5500. 5800. 6100.
#  6400. 6700. 7000. 7300. 7600. 7900.]

# %%
wv,stf = readstarspec("k2-18.dat")
stfl = np.interp(wvref,wv,stf)
refl = netspec*0.01*stfl
albb = np.trapz(refl[:145],x=wvref[:145])/np.trapz(stfl[:145],x=wvref[:145])
print albb
    #srgbs.append(cm.specs2rgb(wvref*1e3,[bbf,]))
# Out:
# 0.06240330564042276

# %%
print wvref[145]
print np.argmin(abs(wv-2.51))
print wv.shape
# Out:
# 2.51
# 145
# (965,)

# %%
plt.plot(wvref,stfl,label="Proxima Cen")
plt.plot(wvref,bbtemp(3000.0,wvref))
plt.xscale('log')
plt.yscale('log')

# %%
plt.plot(stfl/bbtemp(3000.0,wvref))
plt.xscale('log')

# %%
np.trapz(bbtemp(3000.0,wvref),x=wvref)
# Out:
# 0.012247461533465643

# %%
fig,ax=plt.subplots(figsize=(13,4))
for s in range(len(stemps)):
    plt.scatter(stemps[s],1.0,marker='o',color=np.array(rgbs[s])/np.mean(rgbs[s])*albs[s]*3.25,s=1000)
    plt.scatter(stemps[s],1.25,marker='o',color=np.array(srgbs[s])/np.amax(srgbs[s]),s=1000)
    #plt.annotate("%d K"%stemps[s],(stemps[s]-100,1.35))
    #print stemps[s]
    #plt.axvline(stemps[s])
ax.set_facecolor('0.8')
plt.annotate("Stellar Color",(3000,1.35),color='k',fontsize=18)
plt.annotate("Surface Color",(3000,1.1),color='k',fontsize=18)
plt.ylim(0.9,1.4)
plt.xlim(2500,8200)
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    right=False,         # ticks along the top edge are off
    labelleft=False)
plt.xlabel("Stellar Effective Temperature [K]")
plt.title("Ocean Color")
plt.savefig("colorgrid_ocean.png",bbox_inches='tight')

# %%
alb1 = np.zeros(100)
alb2 = np.zeros(100)
albb = np.zeros(100)
teffs = np.linspace(2700,6000,num=100)

# %%
for n in range(100):
    bbf = bbtemp(teffs[n],wvref)
    refl = netspec*0.01*bbf
    alb1[n] = np.trapz(refl[:42],x=wvref[:42])/np.trapz(bbf[:42],x=wvref[:42])
    alb2[n] = np.trapz(refl[42:145],x=wvref[42:145])/np.trapz(bbf[42:145],x=wvref[42:145])
    albb[n] = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bbf[:145],x=wvref[:145])

# %%
plt.plot(teffs,alb1,label="$\lambda<{0.75}$ $\mu$m")
plt.plot(teffs,alb2,label="$\lambda>{0.75}$ $\mu$m")
plt.plot(teffs,albb,label='Bolometric albedo')
plt.legend(loc='best')
plt.xlabel("Star T$_{eff}$ [K]")
plt.ylabel("Albedo")
plt.title("Ocean albedo with different stars")
plt.savefig("ocean_bolometric.png",bbox_inches='tight')

# %%
print teffs[-16],albb[-16]
# Out:
# 5500.0 0.0685934605237809

# %%
bb0 = bbtemp(5772.0,wvref)
refl = netspec*0.01*bb0#*np.pi
alb10 = np.trapz(refl[:42],x=wvref[:42])/np.trapz(bb0[:42],x=wvref[:42])
alb20 = np.trapz(refl[42:145],x=wvref[42:145])/np.trapz(bb0[42:145],x=wvref[42:145])
albb0 = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bb0[:145],x=wvref[:145])

# %%
print albb0,alb10,alb20
# Out:
# 0.06900000000003594 0.07390172204659626 0.06336200982255036

# %%
low = 0.7
high = 4.0
nsteps = 50
target = 0.069
for n in range(nsteps):
    mid = 0.5*(low+high)
    bb0 = bbtemp(5772.0,wvref)
    refl = netspec*0.01*bb0*mid
    alb10 = np.trapz(refl[:42],x=wvref[:42])/np.trapz(bb0[:42],x=wvref[:42])
    alb20 = np.trapz(refl[42:145],x=wvref[42:145])/np.trapz(bb0[42:145],x=wvref[42:145])
    albb0 = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bb0[:145],x=wvref[:145])
    if albb0>target: #Modifier is too large; reduce it
        low=low
        high=mid
    else: #Modifier is too small; increase it
        high=high
        low=mid
    print mid,albb0
# Out:
# 2.35 0.16215000000008445
# 1.525 0.10522500000005479
# 1.1125 0.07676250000003995
# 0.90625 0.06253125000003255
# 1.009375 0.06964687500003626
# 0.9578125 0.06608906250003442
# 0.98359375 0.06786796875003534
# 0.996484375 0.0687574218750358
# 1.0029296875 0.06920214843753604
# 0.99970703125 0.06897978515628593
# 1.00131835937 0.06909096679691099
# 1.00051269531 0.06903537597659844
# 1.00010986328 0.06900758056644218
# 0.999908447266 0.06899368286136406
# 1.00000915527 0.06900063171390312
# 0.99995880127 0.06899715728763359
# 0.999983978271 0.06899889450076836
# 0.999996566772 0.06899976310733576
# 1.00000286102 0.06900019741061943
# 0.999999713898 0.06899998025897759
# 1.00000128746 0.06900008883479851
# 1.00000050068 0.06900003454688805
# 1.00000010729 0.06900000740293281
# 0.999999910593 0.0689999938309552
# 1.00000000894 0.069000000616944
# 0.999999959767 0.0689999972239496
# 0.999999984354 0.06899999892044681
# 0.999999996647 0.06899999976869539
# 1.00000000279 0.06900000019281971
# 0.999999999721 0.06899999998075754
# 1.00000000126 0.06900000008678862
# 1.00000000049 0.06900000003377309
# 1.0000000001 0.06900000000726532
# 0.999999999913 0.06899999999401144
# 1.00000000001 0.06900000000063838
# 0.999999999961 0.06899999999732491
# 0.999999999985 0.06899999999898165
# 0.999999999997 0.06899999999981002
# 1.0 0.0690000000002242
# 1.0 0.06900000000001712
# 0.999999999998 0.06899999999991356
# 0.999999999999 0.06899999999996533
# 0.999999999999 0.06899999999999122
# 1.0 0.06900000000000417
# 0.999999999999 0.0689999999999977
# 0.999999999999 0.06900000000000092
# 0.999999999999 0.06899999999999931
# 0.999999999999 0.06900000000000012
# 0.999999999999 0.06899999999999971
# 0.999999999999 0.06899999999999992

# %%
specvar = "oceanblend"
specinttext = "       real :: %s(%d) = (/"%(specvar,len(wvref))
specinttext += ",".join(["%.4f" % number for number in netspec[0:8]]) + ", &\n"
n=8
while n+8<len(wvref):
    specinttext += "      &          " + ",".join(["%.4f" % number for number in netspec[n:n+8]]) + ", &\n"
    n+=8
specinttext += "      &          " + ",".join(["%.4f" % number for number in netspec[n:]]) + " /)"

# %%
newfilename = "oceanblend_interp_f90.txt"
with open(newfilename,"w") as fileobj:
    fileobj.write(specinttext+'\n')

# %%
print specinttext
# Out:
#        real :: oceanblend(965) = (/7.4504,7.4504,7.4504,7.4504,7.4504,7.4504,7.4504,7.9209, &
#       &          7.5908,7.7804,7.7231,7.3917,7.8809,8.3009,7.2616,7.4463, &
#       &          7.6715,7.1464,7.1269,6.8786,7.3374,7.5517,7.3162,7.2486, &
#       &          7.3795,7.4621,7.1051,7.2486,7.2934,7.2991,7.0212,7.2991, &
#       &          7.3162,7.2991,7.2774,6.8414,7.4509,7.4509,6.7457,7.2415, &
#       &          7.4251,7.1994,7.1994,7.2143,7.4719,7.0378,7.2567,6.8061, &
#       &          6.8259,7.0967,7.0948,6.6781,7.1356,6.8941,6.6781,6.6781, &
#       &          6.4573,6.4608,6.4581,6.4594,6.7042,6.4404,6.1699,6.3690, &
#       &          5.6757,6.1096,6.0919,6.5646,6.0555,5.8156,5.8186,5.7923, &
#       &          5.7396,5.9582,5.9960,5.9803,5.9544,5.9194,5.4549,5.9265, &
#       &          6.1620,5.6901,6.1457,5.4218,5.8797,5.6491,5.8903,5.8852, &
#       &          5.4218,5.6491,5.6393,5.6491,5.6689,5.4052,5.8556,5.4098, &
#       &          5.8314,5.8463,5.2044,5.8768,5.1735,5.1547,5.2031,5.1838, &
#       &          5.1857,5.1569,5.2001,5.6931,5.1957,5.2229,5.2843,5.3206, &
#       &          5.2940,5.2433,5.2476,5.1721,5.1337,5.1063,5.0887,5.0491, &
#       &          5.0269,4.9963,4.9666,4.9345,4.9159,4.9410,4.8935,4.8660, &
#       &          4.8383,4.8244,4.7946,4.7624,4.7575,4.7006,4.6994,4.6519, &
#       &          4.6439,4.6171,4.5682,4.5090,4.4649,4.4284,4.4031,4.3420, &
#       &          4.3090,4.2550,4.1717,4.0584,4.0021,3.7514,3.5185,3.5514, &
#       &          3.4288,3.3862,3.4817,3.2482,2.9337,2.8013,3.3803,3.1094, &
#       &          2.8447,2.1392,2.2825,2.3692,2.1995,1.7184,1.4325,1.7004, &
#       &          7.3115,7.4096,7.5148,7.6195,7.7637,7.8672,7.9654,8.0966, &
#       &          8.2085,8.3388,8.4541,8.5957,8.7065,8.8228,8.9129,9.0165, &
#       &          9.1050,9.2328,9.3510,9.4865,9.5872,9.7006,9.8349,9.9166, &
#       &          10.0332,10.1591,10.3219,10.4173,10.5146 /)

# %%
sbdart_winterp = np.interp(wvref,wlalb,sbdartw)
rgbs = []
srgbs = []
albs = []
stemps = np.linspace(2800,7900,num=18)
print stemps
bbs = []
for s in range(0,len(stemps)):
    bbf = bbtemp(stemps[s],wvref)
    bbs.append(bbtemp(stemps[s]-650.0,wvref))
    refl = sbdart_winterp*bbf
    albb = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bbf[:145],x=wvref[:145])
    albs.append(albb)
    #srgbs.append(cm.specs2rgb(wvref*1e3,[bbf,]))
    rgbs.append(cm.spec2rgb(wvref*1e3,refl,normalization=albb))
srgbs = cm.specs2rgb(wvref*1e3,np.array(bbs))
# Out:
# [2800. 3100. 3400. 3700. 4000. 4300. 4600. 4900. 5200. 5500. 5800. 6100.
#  6400. 6700. 7000. 7300. 7600. 7900.]

# %%
fig,ax=plt.subplots(figsize=(13,4))
for s in range(len(stemps)):
    plt.scatter(stemps[s],1.0,marker='o',color=np.array(rgbs[s])/np.mean(rgbs[s])*albs[s]*3.25,s=1000)
    plt.scatter(stemps[s],1.25,marker='o',color=np.array(srgbs[s])/np.amax(srgbs[s]),s=1000)
    #plt.annotate("%d K"%stemps[s],(stemps[s]-100,1.35))
    #print stemps[s]
    #plt.axvline(stemps[s])
ax.set_facecolor('0.8')
plt.annotate("Stellar Color",(3000,1.35),color='k',fontsize=18)
plt.annotate("Surface Color",(3000,1.1),color='k',fontsize=18)
plt.ylim(0.9,1.4)
plt.xlim(2500,8200)
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    right=False,         # ticks along the top edge are off
    labelleft=False)
plt.xlabel("Stellar Effective Temperature [K]")
plt.title("Ocean Color")
plt.savefig("colorgrid_ocean.png",bbox_inches='tight')

# %%
alb1 = np.zeros(100)
alb2 = np.zeros(100)
albb = np.zeros(100)
teffs = np.linspace(2700,6000,num=100)

# %%
for n in range(100):
    bbf = bbtemp(teffs[n],wvref)
    refl = sbdart_winterp*bbf
    alb1[n] = np.trapz(refl[:42],x=wvref[:42])/np.trapz(bbf[:42],x=wvref[:42])
    alb2[n] = np.trapz(refl[42:145],x=wvref[42:145])/np.trapz(bbf[42:145],x=wvref[42:145])
    albb[n] = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bbf[:145],x=wvref[:145])

# %%
plt.plot(teffs,alb1,label="$\lambda<{0.75}$ $\mu$m")
plt.plot(teffs,alb2,label="$\lambda>{0.75}$ $\mu$m")
plt.plot(teffs,albb,label='Bolometric albedo')
plt.legend(loc='best')
plt.xlabel("Star T$_{eff}$ [K]")
plt.ylabel("Albedo")
plt.title("Ocean albedo with different stars")
#plt.savefig("ocean_bolometric.png",bbox_inches='tight')
# Out:
# Text(0.5,1,'Ocean albedo with different stars')
