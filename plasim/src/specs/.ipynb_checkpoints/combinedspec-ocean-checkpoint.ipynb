# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sbdartw = np.concatenate((np.ones(41)*0.041,
     np.array([.041,.041,.041,.041,.041,.041,.041,.041,.041,.041,.042,
       .043,.044,.044,.046,.047,.049,.050,.052,.054,.055,.056,
      .059,.060,.061,.061,.059,.057,.054,.053,.051,.050,.049,
      .047,.046,.046,.045,.044,.043,.043,.041,.040,.038,.037,
      .037,.036,.033,.032,.031,.029,.027,.024,.023,.021,.018,
      .015,.012,.009,.008,.006,.004,.002,.001,.000,.000,.000]),
      np.zeros(644)))
wlalb = np.zeros(len(sbdartw))
for n in range(0,len(wlalb)):
    wlalb[n] = 0.25 + (4.0-0.25)*float(n)/(len(wlalb)-1)

# %%
plt.plot(wlalb,sbdartw)
plt.xscale('log')

# %%
manifest = {}
with open("manifest.txt","r") as mn:
    lines = mn.read().split('\n')
    for l in lines:
        lfile = l.split()
        if len(lfile)>0:
            manifest[lfile[0]] = lfile[1]

# %%
names = sorted(manifest.keys())
ix = 0
for n in names:
    print ix,n
    ix+=1
# Out:
# 0 andesitefine
# 1 andesitesolid
# 2 basaltsolid
# 3 brownsand
# 4 clearice
# 5 coarsesnow
# 6 dunesand
# 7 finesnow
# 8 frost
# 9 mediumsnow
# 10 seawater
# 11 tapwater
# 12 yellowloam
# 13 yellowsand

# %%
ids = [10,11]

# %%
for i in ids:
    print names[i]
# Out:
# seawater
# tapwater

# %%
weights = np.array([0.0,1.0])

# %%
print np.sum(weights),weights
# Out:
# 1.0 [0. 1.]

# %%
wvref = np.loadtxt("wvref.txt")

# %%
print wvref.shape
# Out:
# (965,)

# %%
specs = np.zeros((len(ids),wvref.shape[0]))

# %%
for idn in range(len(ids)):
    filename = manifest[names[ids[idn]]]
    with open(filename,"r") as fileobj:
        text = fileobj.read().split('\n')
        for k in range(len(text)):
            if text[k].split()[0]=="Additional":
                nhead = k+2
                break
    spec = np.loadtxt(filename,skiprows=nhead,ndmin=2).transpose()
    if spec[0,0] > spec[0,-1]:
        spec = np.flip(spec,axis=1)
    specs[idn,:] = np.interp(wvref,spec[0,:],spec[1,:])

# %%
for idn in range(len(ids)):
    plt.plot(wvref,specs[idn,:],label=names[ids[idn]])
plt.xscale('log')
plt.legend()

# %%
wtspec = np.copy(specs)
for n in range(len(ids)):
    wtspec[n,:] *= weights[n]

# %%
sbdart_winterp = np.interp(wvref,wlalb,sbdartw)*100

# %%
netspec = np.maximum(np.sum(wtspec,axis=0),sbdart_winterp)*2.1

# %%
plt.plot(wvref,netspec)
plt.xscale('log')

# %%
plt.plot(wvref,np.sum(wtspec,axis=0),label="ECOSTRESS Tapwater")
plt.plot(wlalb,sbdartw*100,label="SBDART Seawater")
plt.plot(wvref,netspec,label="New Spectrum")
plt.xscale('log')
plt.xlabel("Wavelength [$\mu$m]")
plt.ylabel("Reflectance [%]")
plt.legend()
plt.title("Water Reflectance Models")
plt.savefig("ocean_refl_components.pdf",bbox_inches='tight')

# %%
for n in range(len(ids)):
    plt.plot(wvref,np.sum(wtspec[:n+1,:],axis=0)*2,label=names[ids[n]])
plt.xscale('log')
plt.legend()
plt.xlim(wvref.min(),wvref.max())
# Out:
# (0.34, 14.01)

# %%
import colormatch as cm

# %%
print np.sum(weights)
# Out:
# 1.0

# %%
def bbtemp(teff,wvref):
    sbk = 5.67e-8
    const = 0.0143877735383
    bbf = 1.0/wvref**5 * (1.0/(np.exp(const/(teff*wvref*1e-6))-1))
    return bbf

# %%
rgbs = []
srgbs = []
albs = []
stemps = np.linspace(2800,7900,num=18)
print stemps
bbs = []
for s in range(0,len(stemps)):
    bbf = bbtemp(stemps[s],wvref)
    bbs.append(bbtemp(stemps[s]-650.0,wvref))
    refl = netspec*0.01*bbf
    albb = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bbf[:145],x=wvref[:145])
    albs.append(albb)
    #srgbs.append(cm.specs2rgb(wvref*1e3,[bbf,]))
    rgbs.append(cm.spec2rgb(wvref*1e3,refl,normalization=albb))
srgbs = cm.specs2rgb(wvref*1e3,np.array(bbs))
# Out:
# [2800. 3100. 3400. 3700. 4000. 4300. 4600. 4900. 5200. 5500. 5800. 6100.
#  6400. 6700. 7000. 7300. 7600. 7900.]

# %%
fig,ax=plt.subplots(figsize=(13,4))
for s in range(len(stemps)):
    plt.scatter(stemps[s],1.0,marker='o',color=np.array(rgbs[s])/np.mean(rgbs[s])*albs[s]*3.25,s=1000)
    plt.scatter(stemps[s],1.25,marker='o',color=np.array(srgbs[s])/np.amax(srgbs[s]),s=1000)
    #plt.annotate("%d K"%stemps[s],(stemps[s]-100,1.35))
    #print stemps[s]
    #plt.axvline(stemps[s])
ax.set_facecolor('0.8')
plt.annotate("Stellar Color",(3000,1.35),color='k',fontsize=18)
plt.annotate("Surface Color",(3000,1.1),color='k',fontsize=18)
plt.ylim(0.9,1.4)
plt.xlim(2500,8200)
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    right=False,         # ticks along the top edge are off
    labelleft=False)
plt.xlabel("Stellar Effective Temperature [K]")
plt.title("Ocean Color")
plt.savefig("colorgrid_ocean.png",bbox_inches='tight')

# %%
alb1 = np.zeros(100)
alb2 = np.zeros(100)
albb = np.zeros(100)
teffs = np.linspace(2700,6000,num=100)

# %%
for n in range(100):
    bbf = bbtemp(teffs[n],wvref)
    refl = netspec*0.01*bbf
    alb1[n] = np.trapz(refl[:42],x=wvref[:42])/np.trapz(bbf[:42],x=wvref[:42])
    alb2[n] = np.trapz(refl[42:145],x=wvref[42:145])/np.trapz(bbf[42:145],x=wvref[42:145])
    albb[n] = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bbf[:145],x=wvref[:145])

# %%
plt.plot(teffs,alb1,label="$\lambda<{0.75}$ $\mu$m")
plt.plot(teffs,alb2,label="$\lambda>{0.75}$ $\mu$m")
plt.plot(teffs,albb,label='Bolometric albedo')
plt.legend(loc='best')
plt.xlabel("Star T$_{eff}$ [K]")
plt.ylabel("Albedo")
plt.title("Ocean albedo with different stars")
plt.savefig("ocean_bolometric.png",bbox_inches='tight')

# %%
print teffs[-16],albb[-16]
# Out:
# 5500.0 0.06915802680817525

# %%
specvar = "oceanblend"
specinttext = "       real :: %s(%d) = (/"%(specvar,len(wvref))
specinttext += ",".join(["%.4f" % number for number in netspec[0:8]]) + ", &\n"
n=8
while n+8<len(wvref):
    specinttext += "      &          " + ",".join(["%.4f" % number for number in netspec[n:n+8]]) + ", &\n"
    n+=8
specinttext += "      &          " + ",".join(["%.4f" % number for number in netspec[n:]]) + " /)"

# %%
newfilename = "oceanblend_interp_f90.txt"
with open(newfilename,"w") as fileobj:
    fileobj.write(specinttext+'\n')

# %%
print specinttext
# Out:
#        real :: oceanblend(965) = (/8.6100,8.6100,8.6100,8.6100,8.6100,8.6100,8.6100,8.6100, &
#       &          8.6100,8.6100,8.6100,8.6100,8.6100,8.6100,8.6100,8.6100, &
#       &          8.6100,9.0300,9.2400,9.8700,10.5000,11.3400,11.7600,12.6000, &
#       &          12.8100,11.9700,11.1300,10.5000,9.8700,9.6600,9.2400,9.0300, &
#       &          8.4000,7.7700,7.5600,6.7200,6.0900,5.7601,5.2149,5.5982, &
#       &          5.7401,5.5656,5.5656,5.5772,5.7763,5.4407,5.6099,5.2616, &
#       &          5.2769,5.4863,5.4848,5.1626,5.5163,5.3296,5.1626,5.1626, &
#       &          4.9919,4.9946,4.9925,4.9936,5.1828,4.9789,4.7697,4.9237, &
#       &          4.3877,4.7231,4.7095,5.0749,4.6813,4.4959,4.4982,4.4778, &
#       &          4.4371,4.6061,4.6353,4.6231,4.6032,4.5761,4.2170,4.5816, &
#       &          4.7636,4.3989,4.7510,4.1914,4.5454,4.3672,4.5536,4.5497, &
#       &          4.1914,4.3672,4.3596,4.3672,4.3825,4.1786,4.5268,4.1822, &
#       &          4.5081,4.5196,4.0234,4.5431,3.9995,3.9850,4.0223,4.0074, &
#       &          4.0089,3.9866,4.0200,4.4012,4.0167,4.0377,4.0851,4.1132, &
#       &          4.0926,4.0534,4.0568,3.9984,3.9687,3.9475,3.9339,3.9033, &
#       &          3.8861,3.8625,3.8395,3.8147,3.8004,3.8197,3.7830,3.7617, &
#       &          3.7403,3.7296,3.7065,3.6817,3.6779,3.6339,3.6330,3.5962, &
#       &          3.5901,3.5694,3.5316,3.4858,3.4517,3.4235,3.4039,3.3566, &
#       &          3.3312,3.2894,3.2250,3.1374,3.0939,2.9001,2.7200,2.7455, &
#       &          2.6507,2.6178,2.6916,2.5111,2.2680,2.1656,2.6132,2.4038, &
#       &          2.1991,1.6537,1.7645,1.8315,1.7004,1.3285,1.1074,1.3145, &
#       &          0.9778,1.2685,1.2194,1.2591,1.4264,1.5254,1.6796,1.9632, &
#       &          2.1370,2.4615,2.7867,3.0683,3.4834,3.8237,4.2527,4.6603, &
#       &          4.9764,5.4629,5.8116,6.2535,6.5925,6.8511,7.1084,7.2837, &
#       &          7.4632,7.5555,7.6641,7.7101,7.7935,7.8964,7.9813,8.0281, &
#       &          8.1326,8.2135,8.2674,8.3340,8.3735,8.3848,8.4327,8.3861, &
#       &          8.3656,8.3182,8.2603,8.1835,8.0998,7.9879,7.8703,7.7641, &
#       &          7.6862,7.5938,7.4870,7.3975,7.2890,7.2033,7.1054,7.0528, &
#       &          6.9413,6.8987,6.7921,6.7285,6.6563,6.5862,6.5230,6.4614, &
#       &          6.3768,6.3468,6.2919,6.2568,6.1882,6.1617,6.0936,6.0290, &
#       &          6.0019,5.9537,5.9117,5.8579,5.8185,5.7956,5.7597,5.7276, &
#       &          5.7010,5.6725,5.6259,5.5939,5.5776,5.5342,5.5207,5.4968, &
#       &          5.4731,5.4575,5.4180,5.4202,5.3891,5.3712,5.3543,5.3331, &
#       &          5.3131,5.2817,5.2771,5.2617,5.2293,5.2337,5.2035,5.1973, &
#       &          5.1769,5.1593,5.1449,5.1297,5.1086,5.0837,5.0866,5.0680, &
#       &          5.0597,5.0457,5.0301,5.0094,4.9950,4.9808,4.9662,4.9647, &
#       &          4.9528,4.9331,4.9142,4.9043,4.8923,4.8907,4.8904,4.8686, &
#       &          4.8508,4.8395,4.8280,4.8225,4.8098,4.8114,4.7849,4.7709, &
#       &          4.7629,4.7472,4.7433,4.7357,4.7302,4.7239,4.7186,4.7100, &
#       &          4.7005,4.6854,4.6742,4.6800,4.6643,4.6502,4.6384,4.6288, &
#       &          4.6323,4.6289,4.6217,4.6238,4.6136,4.6042,4.6039,4.5949, &
#       &          4.5817,4.5781,4.5768,4.5680,4.5594,4.5486,4.5470,4.5530, &
#       &          4.5441,4.5366,4.5282,4.5239,4.5283,4.5201,4.5079,4.5091, &
#       &          4.5079,4.5028,4.4928,4.4850,4.4875,4.4824,4.4794,4.4929, &
#       &          4.4842,4.4760,4.4827,4.4816,4.4796,4.4805,4.4821,4.4741, &
#       &          4.4721,4.4715,4.4692,4.4763,4.4856,4.4798,4.4675,4.4702, &
#       &          4.4730,4.4727,4.4729,4.4783,4.4735,4.4683,4.4692,4.4639, &
#       &          4.4684,4.4657,4.4453,4.4400,4.4552,4.4601,4.4572,4.4445, &
#       &          4.4354,4.4432,4.4429,4.4296,4.4321,4.4041,4.3918,4.4105, &
#       &          4.4310,4.4194,4.4144,4.3459,4.3066,4.3317,4.3847,4.3818, &
#       &          4.3841,4.3496,4.3021,4.2975,4.3190,4.3124,4.3100,4.2832, &
#       &          4.1842,4.1561,4.2184,4.2842,4.2751,4.2073,4.0766,4.0114, &
#       &          4.0714,4.1286,4.1431,4.1598,4.1786,4.1482,4.0526,3.9942, &
#       &          4.0275,4.0987,4.1354,4.1168,3.9071,3.7592,3.8145,4.0101, &
#       &          4.0623,4.0533,4.0281,3.7681,3.6266,3.6794,3.9063,3.8414, &
#       &          3.6487,3.5340,3.6221,3.7912,3.8620,3.7787,3.7152,3.7026, &
#       &          3.6401,3.5811,3.4539,3.3147,3.3155,3.3826,3.5150,3.5338, &
#       &          3.4505,3.2138,2.9946,3.0031,3.1687,3.2797,3.2421,3.1923, &
#       &          3.0661,2.9014,2.8597,2.8950,2.9967,2.7877,2.5615,2.5773, &
#       &          2.7607,3.1036,3.1137,2.7483,2.4580,2.4524,2.6601,2.8446, &
#       &          2.6615,2.3116,2.0539,2.0871,2.3828,2.7313,2.6384,2.3990, &
#       &          2.3777,2.5154,2.7626,2.7618,2.7011,2.8689,3.0405,3.3237, &
#       &          3.5784,3.2856,3.0299,2.7883,2.7653,3.2715,3.8505,4.0199, &
#       &          4.0043,3.9528,4.0513,4.4006,4.6546,4.6538,4.5513,4.4284, &
#       &          4.4509,4.5898,4.7203,4.9886,5.0597,5.0029,5.0255,5.0112, &
#       &          4.9786,4.9478,4.9211,4.9202,4.9346,4.9485,4.7265,4.3834, &
#       &          4.1913,3.9960,3.9525,4.1482,4.2598,3.9459,3.4997,3.0630, &
#       &          2.9382,3.1959,3.8237,4.1536,4.0049,3.5234,3.0505,2.9005, &
#       &          2.9765,3.3332,3.7483,3.8791,3.7534,3.5495,3.2767,3.0490, &
#       &          3.0996,3.3365,3.6030,3.5365,3.2100,3.0448,3.1009,3.3088, &
#       &          3.5731,3.8200,3.7998,3.6323,3.5885,3.6466,3.7144,3.8311, &
#       &          4.0670,4.2050,4.0256,3.6766,3.4791,3.4644,3.5290,3.7098, &
#       &          3.9504,3.9272,3.5399,3.2743,3.2254,3.2825,3.4470,3.7412, &
#       &          3.9700,4.0312,4.0746,4.0301,3.9083,3.7810,3.6711,3.6335, &
#       &          3.7157,3.8702,3.9714,3.9317,3.7918,3.6433,3.5464,3.5514, &
#       &          3.6543,3.8265,4.0059,4.0443,4.0000,3.9565,3.9003,3.8198, &
#       &          3.6990,3.6177,3.6058,3.6248,3.6684,3.7298,3.7971,3.8520, &
#       &          3.8600,3.9001,3.9419,3.8995,3.8114,3.7541,3.7381,3.7709, &
#       &          3.8030,3.7982,3.7536,3.7003,3.6817,3.6954,3.7392,3.8079, &
#       &          3.8586,3.8572,3.8642,3.8726,3.8458,3.7821,3.7149,3.6632, &
#       &          3.6446,3.6640,3.7137,3.7799,3.8273,3.8425,3.8233,3.8025, &
#       &          3.7799,3.7553,3.7293,3.7070,3.7059,3.7144,3.7289,3.7415, &
#       &          3.7523,3.7517,3.7473,3.7398,3.7391,3.7383,3.7399,3.7386, &
#       &          3.7303,3.7198,3.7107,3.7008,3.6964,3.6988,3.7034,3.7045, &
#       &          3.6975,3.6886,3.6802,3.6684,3.6677,3.6677,3.6677,3.6659, &
#       &          3.6579,3.6543,3.6550,3.6588,3.6692,3.6701,3.6669,3.6608, &
#       &          3.6468,3.6382,3.6330,3.6330,3.6397,3.6422,3.6466,3.6483, &
#       &          3.6446,3.6377,3.6318,3.6220,3.6045,3.5985,3.5972,3.5957, &
#       &          3.5962,3.5938,3.5844,3.5751,3.5686,3.5644,3.5535,3.5462, &
#       &          3.5445,3.5448,3.5461,3.5438,3.5438,3.5408,3.5234,3.5110, &
#       &          3.5034,3.4873,3.4781,3.4674,3.4500,3.4417,3.4332,3.4303, &
#       &          3.4304,3.4311,3.4323,3.4355,3.4369,3.4278,3.4235,3.4144, &
#       &          3.3924,3.3796,3.3611,3.3542,3.3524,3.3547,3.3579,3.3531, &
#       &          3.3376,3.3269,3.3050,3.2932,3.2900,3.2904,3.2855,3.2808, &
#       &          3.2770,3.2718,3.2571,3.2477,3.2381,3.2320,3.2197,3.2102, &
#       &          3.2061,3.1836,3.1709,3.1442,3.1226,3.1107,3.0931,3.0835, &
#       &          3.0655,3.0503,3.0490,3.0504,3.0510,3.0451,3.0336,3.0236, &
#       &          3.0066,2.9815,2.9726,2.9564,2.9434,2.9370,2.9328,2.9281, &
#       &          2.9157,2.9023,2.8746,2.8481,2.8380,2.8201,2.8108,2.7930, &
#       &          2.7838,2.7673,2.7500,2.7285,2.7204,2.7148,2.7005,2.6834, &
#       &          2.6753,2.6623,2.6541,2.6351,2.6275,2.6191,2.6050,2.5848, &
#       &          2.5662,2.5553,2.5354,2.5141,2.4971,2.4784,2.4593,2.4345, &
#       &          2.4208,2.4068,2.3911,2.3759,2.3648,2.3510,2.3356,2.3197, &
#       &          2.3095,2.3013,2.2720,2.2553,2.2397,2.2213,2.2013,2.1794, &
#       &          2.1650,2.1463,2.1311,2.1186,2.1050,2.0864,2.0737,2.0565, &
#       &          2.0429,2.0195,2.0062,1.9902,1.9761,1.9637,1.9596,1.9513, &
#       &          1.9457,1.9323,1.9214,1.9073,1.8947,1.8887,1.8845,1.8754, &
#       &          1.8665,1.8625,1.8667,1.8683,1.8688,1.8629,1.8604,1.8566, &
#       &          1.8581,1.8605,1.8759,1.8851,1.8904,1.8910,1.8985,1.9127, &
#       &          1.9223,1.9357,1.9488,1.9619,1.9857,2.0006,2.0286,2.0463, &
#       &          2.0739,2.0935,2.1283,2.1477,2.1855,2.2233,2.2515,2.2917, &
#       &          2.3225,2.3720,2.4281,2.4597,2.5075,2.5498,2.5800,2.6260, &
#       &          2.6819,2.7217,2.7875,2.8485,2.9179,2.9587,3.0250,3.0838, &
#       &          3.1427,3.1808,3.2408,3.3011,3.3685,3.4349,3.5062,3.5745, &
#       &          3.6213,3.6889,3.7709,3.8521,3.9392,4.0205,4.1067,4.1912, &
#       &          4.2751,4.3477,4.4270,4.5041,4.5897,4.6982,4.7881,4.8784, &
#       &          4.9677,5.0490,5.1315,5.2068,5.3118,5.3850,5.4600,5.5371, &
#       &          5.6523,5.7281,5.8095,5.8904,6.0019,6.0819,6.1578,6.2592, &
#       &          6.3457,6.4465,6.5356,6.6451,6.7307,6.8207,6.8903,6.9704, &
#       &          7.0388,7.1376,7.2289,7.3337,7.4116,7.4993,7.6031,7.6662, &
#       &          7.7564,7.8537,7.9795,8.0533,8.1285 /)

# %%
sbdart_winterp = np.interp(wvref,wlalb,sbdartw)
rgbs = []
srgbs = []
albs = []
stemps = np.linspace(2800,7900,num=18)
print stemps
bbs = []
for s in range(0,len(stemps)):
    bbf = bbtemp(stemps[s],wvref)
    bbs.append(bbtemp(stemps[s]-650.0,wvref))
    refl = sbdart_winterp*bbf
    albb = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bbf[:145],x=wvref[:145])
    albs.append(albb)
    #srgbs.append(cm.specs2rgb(wvref*1e3,[bbf,]))
    rgbs.append(cm.spec2rgb(wvref*1e3,refl,normalization=albb))
srgbs = cm.specs2rgb(wvref*1e3,np.array(bbs))
# Out:
# [2800. 3100. 3400. 3700. 4000. 4300. 4600. 4900. 5200. 5500. 5800. 6100.
#  6400. 6700. 7000. 7300. 7600. 7900.]

# %%
fig,ax=plt.subplots(figsize=(13,4))
for s in range(len(stemps)):
    plt.scatter(stemps[s],1.0,marker='o',color=np.array(rgbs[s])/np.mean(rgbs[s])*albs[s]*3.25,s=1000)
    plt.scatter(stemps[s],1.25,marker='o',color=np.array(srgbs[s])/np.amax(srgbs[s]),s=1000)
    #plt.annotate("%d K"%stemps[s],(stemps[s]-100,1.35))
    #print stemps[s]
    #plt.axvline(stemps[s])
ax.set_facecolor('0.8')
plt.annotate("Stellar Color",(3000,1.35),color='k',fontsize=18)
plt.annotate("Surface Color",(3000,1.1),color='k',fontsize=18)
plt.ylim(0.9,1.4)
plt.xlim(2500,8200)
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    right=False,         # ticks along the top edge are off
    labelleft=False)
plt.xlabel("Stellar Effective Temperature [K]")
plt.title("Ocean Color")
plt.savefig("colorgrid_ocean.png",bbox_inches='tight')

# %%
alb1 = np.zeros(100)
alb2 = np.zeros(100)
albb = np.zeros(100)
teffs = np.linspace(2700,6000,num=100)

# %%
for n in range(100):
    bbf = bbtemp(teffs[n],wvref)
    refl = sbdart_winterp*bbf
    alb1[n] = np.trapz(refl[:42],x=wvref[:42])/np.trapz(bbf[:42],x=wvref[:42])
    alb2[n] = np.trapz(refl[42:145],x=wvref[42:145])/np.trapz(bbf[42:145],x=wvref[42:145])
    albb[n] = np.trapz(refl[:145],x=wvref[:145])/np.trapz(bbf[:145],x=wvref[:145])

# %%
plt.plot(teffs,alb1,label="$\lambda<{0.75}$ $\mu$m")
plt.plot(teffs,alb2,label="$\lambda>{0.75}$ $\mu$m")
plt.plot(teffs,albb,label='Bolometric albedo')
plt.legend(loc='best')
plt.xlabel("Star T$_{eff}$ [K]")
plt.ylabel("Albedo")
plt.title("Ocean albedo with different stars")
#plt.savefig("ocean_bolometric.png",bbox_inches='tight')
# Out:
# Text(0.5,1,'Ocean albedo with different stars')
